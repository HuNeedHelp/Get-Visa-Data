# %% [markdown]
# # Config and Main Function

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import time
import re
import random
import os
path = "D:\iCloudDrive\学习资料\VisaFreeData\getData\\visa_G" # 用于创建免签关系矩阵G
# path = os.getcwd() + "\\visa_G"
os.chdir(path)

# 待收集国家名称
"""
nations = {
    "Afghanistan": ["Afghan", "Afghanistan"],
    "Armenia": ["Armenian", "Armenia"],
    "Australia": ["Australian", "Australia"],
    "Azerbaijan": ["Azerbaijani", "Azerbaijan"],
    "Bahrain": ["Bahraini", "Bahrain"],
    "Bangladesh": ["Bangladeshi", "Bangladesh"],
    "Belarus": ["Belarusian", "Belarus"],
    "Brunei": ["Bruneian", "Brunei"],
    "Cambodia": ["Cambodian", "Cambodia"],
    "China": ["Chinese", "China"],
    "Cyprus": ["Cypriot", "Cyprus"],
    "Estonia": ["Estonian", "Estonia"],
    "Fiji": ["Fijian", "Fiji"],
    "Georgia": ["Georgian", "Georgia"],
    "HongKongSARChina": ["Chinese_citizens_of_Hong_Kong", "Hong Kong"],
    "India": ["Indian", "India"],
    "Indonesia": ["Indonesian", "Indonesia"],
    "Iran": ["Iranian", "Iran"],
    "Iraq": ["Iraqi", "Iraq"],
    "Israel": ["Israeli", "Israel"],
    "Japan": ["Japanese", "Japan"],
    "Jordan": ["Jordanian", "Jordan"],
    "Kazakhstan": ["Kazakhstani", "Kazakhstan"],
    "Kiribati": ["Kiribati", "Kiribati"],
    "Kuwait": ["Kuwaiti", "Kuwait"],
    "Kyrgyzstan": ["Kyrgyzstani", "Kyrgyzstan"],
    "Laos": ["Laotian", "Laos"],
    "Latvia": ["Latvian", "Latvia"],
    "Lebanon": ["Lebanese", "Lebanon"],
    "Lithuania": ["Lithuanian", "Lithuania"],
    "Malaysia": ["Malaysian", "Malaysia"],
    "Moldova": ["Moldovan", "Moldova"],
    "Mongolia": ["Mongolian", "Mongolia"],
    "Myanmar": ["Burmese", "Myanmar"],
    "Nepal": ["Nepalese", "Nepal"],
    "NewZealand": ["New_Zealand", "New Zealand"],
    "Oman": ["Omani", "Oman"],
    "Pakistan": ["Pakistani", "Pakistan"],
    "PapuaNewGuinea": ["Papua_New_Guinean", "Papua New Guinea"],
    "Philippines": ["Filipino", "Philippines"],
    "Qatar": ["Qatari", "Qatar"],
    "Russia": ["Russian", "Russia"],
    "SaudiArabia": ["Saudi", "Saudi Arabia"],
    "Singapore": ["Singaporean", "Singapore"],
    "SriLanka": ["Sri_Lankan", "Sri Lanka"],
    "Tajikistan": ["Tajikistani", "Tajikistan"],
    "Thailand": ["Thai", "Thailand"],
    "Tonga": ["Tongan", "Tonga"],
    "Turkey": ["Turkish", "Turkey"],
    "UnitedArabEmirates": ["Emirati", "United Arab Emirates"],
    "Uzbekistan": ["Uzbekistani", "Uzbekistan"],
    "Vanuatu": ["Vanuatuan", "Vanuatu"],
    "Vietnam": ["Vietnamese", "Vietnam"],
    "Yemen": ["Yemeni", "Yemen"],
    "SouthKorea": ["South_Korean", "South Korea"],
    "Syria": ["Syrian", "Syria"],
    "Bhutan": ["Bhutanese", "Bhutan"]
}
"""

nations = {
    "Afghanistan": "for_Afghan_citizens",
    "Albania": "for_Albanian_citizens",
    "Algeria": "for_Algerian_citizens",
    "Andorra": "for_Andorran_citizens",
    "Angola": "for_Angolan_citizens",
    "Antigua and Barbuda": "for_Antigua_and_Barbuda_citizens",
    "Argentina": "for_Argentine_citizens",
    "Armenia": "for_Armenian_citizens",
    "Australia": "for_Australian_citizens",
    "Austria": "for_Austrian_citizens",
    "Azerbaijan": "for_Azerbaijani_citizens",
    "Bahamas": "for_Bahamian_citizens",
    "Bahrain": "for_Bahraini_citizens",
    "Bangladesh": "for_Bangladeshi_citizens",
    "Barbados": "for_Barbadian_citizens",
    "Belarus": "for_Belarusian_citizens",
    "Belgium": "for_Belgian_citizens",
    "Belize": "for_Belizean_citizens",
    "Benin": "for_Beninese_citizens",
    "Bhutan": "for_Bhutanese_citizens",
    "Bolivia": "for_Bolivian_citizens",
    "Bosnia and Herzegovina": "for_Bosnia_and_Herzegovina_citizens",
    "Botswana": "for_Botswanan_citizens",
    "Brazil": "for_Brazilian_citizens",
    "Brunei": "for_Bruneian_citizens",
    "Bulgaria": "for_Bulgarian_citizens",
    "Burkina Faso": "for_Burkinabe_citizens",
    "Burundi": "for_Burundian_citizens",
    "Cape Verde": "for_Cape_Verdean_citizens",
    "Cambodia": "for_Cambodian_citizens",
    "Cameroon": "for_Cameroonian_citizens",
    "Canada": "for_Canadian_citizens",
    "Central African Republic": "for_Central_African_citizens",
    "Chad": "for_Chadian_citizens",
    "Chile": "for_Chilean_citizens",
    "China": "for_Chinese_citizens",
    "Colombia": "for_Colombian_citizens",
    "Comoros": "for_Comorian_citizens",
    "Congo (Congo-Brazzaville)": "for_Congolese_citizens",
    "Costa Rica": "for_Costa_Rican_citizens",
    "Croatia": "for_Croatian_citizens",
    "Cuba": "for_Cuban_citizens",
    "Cyprus": "for_Cypriot_citizens",
    "Czech Republic": "for_Czech_citizens",
    "Denmark": "for_Danish_citizens",
    "Djibouti": "for_Djiboutian_citizens",
    "Dominica": "for_Dominican_citizens",
    "Dominican Republic": "for_Dominican_citizens",
    "Ecuador": "for_Ecuadorian_citizens",
    "Egypt": "for_Egyptian_citizens",
    "El Salvador": "for_Salvadoran_citizens",
    "Equatorial Guinea": "for_Equatorial_Guinean_citizens",
    "Eritrea": "for_Eritrean_citizens",
    "Estonia": "for_Estonian_citizens",
    "Eswatini": "for_Swazi_citizens",
    "Ethiopia": "for_Ethiopian_citizens",
    "Fiji": "for_Fijian_citizens",
    "Finland": "for_Finnish_citizens",
    "France": "for_French_citizens",
    "Gabon": "for_Gabonese_citizens",
    "Gambia": "for_Gambian_citizens",
    "Georgia": "for_Georgian_citizens",
    "Germany": "for_German_citizens",
    "Ghana": "for_Ghanaian_citizens",
    "Greece": "for_Greek_citizens",
    "Grenada": "for_Grenadian_citizens",
    "Guatemala": "for_Guatemalan_citizens",
    "Guinea": "for_Guinean_citizens",
    "Guinea-Bissau": "for_Guinea-Bissauan_citizens",
    "Guyana": "for_Guyanese_citizens",
    "Haiti": "for_Haitian_citizens",
    "Honduras": "for_Honduran_citizens",
    "Hungary": "for_Hungarian_citizens",
    "Iceland": "for_Icelandic_citizens",
    "India": "for_Indian_citizens",
    "Indonesia": "for_Indonesian_citizens",
    "Iran": "for_Iranian_citizens",
    "Iraq": "for_Iraqi_citizens",
    "Ireland": "for_Irish_citizens",
    "Israel": "for_Israeli_citizens",
    "Italy": "for_Italian_citizens",
    "Jamaica": "for_Jamaican_citizens",
    "Japan": "for_Japanese_citizens",
    "Jordan": "for_Jordanian_citizens",
    "Kazakhstan": "for_Kazakhstani_citizens",
    "Kenya": "for_Kenyan_citizens",
    "Kiribati": "for_I-Kiribati_citizens",
    "Korea (North)": "for_North_Korean_citizens",
    "Korea (South)": "for_South_Korean_citizens",
    "Kuwait": "for_Kuwaiti_citizens",
    "Kyrgyzstan": "for_Kyrgyzstani_citizens",
    "Laos": "for_Lao_citizens",
    "Latvia": "for_Latvian_citizens",
    "Lebanon": "for_Lebanese_citizens",
    "Lesotho": "for_Basotho_citizens",
    "Liberia": "for_Liberian_citizens",
    "Libya": "for_Libyan_citizens",
    "Liechtenstein": "for_Liechtensteiner_citizens",
    "Lithuania": "for_Lithuanian_citizens",
    "Luxembourg": "for_Luxembourger_citizens",
    "Madagascar": "for_Malagasy_citizens",
    "Malawi": "for_Malawian_citizens",
    "Malaysia": "for_Malaysian_citizens",
    "Maldives": "for_Maldivian_citizens",
    "Mali": "for_Malian_citizens",
    "Malta": "for_Maltese_citizens",
    "Marshall Islands": "for_Marshallese_citizens",
    "Mauritania": "for_Mauritanian_citizens",
    "Mauritius": "for_Mauritian_citizens",
    "Mexico": "for_Mexican_citizens",
    "Micronesia": "for_Micronesian_citizens",
    "Moldova": "for_Moldovan_citizens",
    "Monaco": "for_Monégasque_citizens",
    "Mongolia": "for_Mongolian_citizens",
    "Montenegro": "for_Montenegrin_citizens",
    "Morocco": "for_Moroccan_citizens",
    "Mozambique": "for_Mozambican_citizens",
    "Myanmar (Burma)": "for_Burmese_citizens",
    "Namibia": "for_Namibian_citizens",
    "Nauru": "for_Nauruan_citizens",
    "Nepal": "for_Nepali_citizens",
    "Netherlands": "for_Dutch_citizens",
    "New Zealand": "for_New_Zealander_citizens",
    "Nicaragua": "for_Nicaraguan_citizens",
    "Niger": "for_Nigerien_citizens",
    "Nigeria": "for_Nigerian_citizens",
    "North Macedonia": "for_Macedonian_citizens",
    "Norway": "for_Norwegian_citizens",
    "Oman": "for_Omani_citizens",
    "Pakistan": "for_Pakistani_citizens",
    "Palau": "for_Palauan_citizens",
    "Palestine": "for_Palestinian_citizens",
    "Panama": "for_Panamanian_citizens",
    "Papua New Guinea": "for_Papua_New_Guinean_citizens",
    "Paraguay": "for_Paraguayan_citizens",
    "Peru": "for_Peruvian_citizens",
    "Philippines": "for_Filipino_citizens",
    "Poland": "for_Polish_citizens",
    "Portugal": "for_Portuguese_citizens",
    "Qatar": "for_Qatari_citizens",
    "Romania": "for_Romanian_citizens",
    "Russia": "for_Russian_citizens",
    "Rwanda": "for_Rwandan_citizens",
    "Saint Kitts and Nevis": "for_Kittitian_or_Nevisian_citizens",
    "Saint Lucia": "for_Saint_Lucian_citizens",
    "Saint Vincent and the Grenadines": "for_Vincentian_citizens",
    "Samoa": "for_Samoan_citizens",
    "San Marino": "for_Sammarinese_citizens",
    "Sao Tome and Principe": "for_São_Toméan_citizens",
    "Saudi Arabia": "for_Saudi_citizens",
    "Senegal": "for_Senegalese_citizens",
    "Serbia": "for_Serbian_citizens",
    "Seychelles": "for_Seychellois_citizens",
    "Sierra Leone": "for_Sierra_Leonean_citizens",
    "Singapore": "for_Singaporean_citizens",
    "Slovakia": "for_Slovak_citizens",
    "Slovenia": "for_Slovene_citizens",
    "Solomon Islands": "for_Solomon_Islands_citizens",
    "Somalia": "for_Somali_citizens",
    "South Africa": "for_South_African_citizens",
    "Spain": "for_Spanish_citizens",
    "Sri Lanka": "for_Sri_Lankan_citizens",
    "Sudan": "for_Sudanese_citizens",
    "Suriname": "for_Surinamese_citizens",
    "Sweden": "for_Swedish_citizens",
    "Switzerland": "for_Swiss_citizens",
    "Syria": "for_Syrian_citizens",
    "Tajikistan": "for_Tajikistani_citizens",
    "Tanzania": "for_Tanzanian_citizens",
    "Thailand": "for_Thai_citizens",
    "Timor-Leste": "for_Timorese_citizens",
    "Togo": "for_Togolese_citizens",
    "Tonga": "for_Tongan_citizens",
    "Trinidad and Tobago": "for_Trinidad_and_Tobago_citizens",
    "Tunisia": "for_Tunisian_citizens",
    "Turkey": "for_Turkish_citizens",
    "Turkmenistan": "for_Turkmen_citizens",
    "Tuvalu": "for_Tuvaluan_citizens",
    "Uganda": "for_Ugandan_citizens",
    "Ukraine": "for_Ukrainian_citizens",
    "United Arab Emirates": "for_Emirati_citizens",
    "United Kingdom": "for_British_citizens",
    "United States": "for_American_citizens",
    "Uruguay": "for_Uruguayan_citizens",
    "Uzbekistan": "for_Uzbekistani_citizens",
    "Vanuatu": "for_Vanuatuan_citizens",
    "Vatican City": "for_Vatican_citizens",
    "Venezuela": "for_Venezuelan_citizens",
    "Vietnam": "for_Vietnamese_citizens",
    "Yemen": "for_Yemeni_citizens",
    "Zambia": "for_Zambian_citizens",
    "Zimbabwe": "for_Zimbabwean_citizens"
}

# 创建反向字典用于从官方名字到自己设定的国家名字
name_to_key = {value[1]: key for key, value in nations.items()}

# 目标时间点
date = 201702 #201305 #201404 #201509 #20190129 #202004 #202105 #20220526 #202307 #202412 #201604 

nations_list = list(nations.keys())

# 初始化免签网络矩阵
G = pd.DataFrame(0, index=nations_list, columns=nations_list)

# save_result_dict字典用于保存57个国家分别的被免签政策
save_result_dict = {}

# 定义获取免签国家列表的函数
def fetch_visa_free_countries(country, citizen_name):
    if country == 'HongKongSARChina':
        url = f"https://web.archive.org/web/{date}/https://en.wikipedia.org/wiki/Visa_requirements_for_{citizen_name}"
    else:
        url = f"https://web.archive.org/web/{date}/https://en.wikipedia.org/wiki/Visa_requirements_for_{citizen_name}_citizens"

    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code == 200:
            print(f"请求{country}成功")
        soup = BeautifulSoup(response.text, 'html.parser')

        # 找到免签列表（通常在页面的表格中）
        visa_tables = soup.find_all('table', {'class': 'wikitable'})
        # 遍历找到的所有表格
        countries_visa_policy = [[], [], []] # 分别存放Visa not required; Visa on arrival; eVisa的country
        for table_idx, visa_table in enumerate(visa_tables):
            print(f"正在处理第 {table_idx + 1} 个表格...")
            if not visa_table:                         # 跳过空表格
                continue

            for row in visa_table.find_all('tr')[1:]:  # 跳过表头
                cells = row.find_all(['td', 'th'])

                if cells:                              # 跳过空单元格
                    """if len(cells) >= 3:  # 如果一行的单元格数大于或等于 3
                        country_name = cells[1].get_text(strip=True)  # 国家在第 2 列
                        visa_state = cells[2].get_text(strip=True)    # 免签信息在第 3 列"""
                    if len(cells) >= 2:  # 如果一行的单元格数为 2
                        country_name = cells[0].get_text(strip=True)  # 国家在第 1 列
                        visa_state = cells[1].get_text(strip=True)    # 免签信息在第 2 列
                    else:
                        continue  # 跳过其他不符合的行

                    country_name = re.sub(r'\[\d+\]', '', country_name).strip()     # 匹配掉方括号内容
                    visa_state = re.sub(r'\[\d+\]', '', visa_state).strip()
                    print(country_name, "|", visa_state)   # 获取每一行country的visa policy

                    # 转换回自己设定的国家名字
                    if country_name in name_to_key.keys():
                        country_name = name_to_key[country_name]            
                    
                    # 分类匹配
                    if "not required" in visa_state.lower() or "free" in visa_state.lower() or "unlimited" in visa_state.lower():
                        countries_visa_policy[0].append(country_name)
                    elif "on arrival" in visa_state.lower() or "voa" in visa_state.lower():
                        countries_visa_policy[1].append(country_name)
                    elif "evisa" in visa_state.lower() or "eta" in visa_state.lower(): 
                        countries_visa_policy[2].append(country_name)
                    elif "days" in visa_state.lower() or "month" in visa_state.lower():
                        countries_visa_policy[0].append(country_name)
        save_result_dict[country] = countries_visa_policy
        return countries_visa_policy

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {country}: {e}")
        return 0
 


def update_matrix(country, countries_visa_policy, G=G):
    # 遍历 countries_visa_policy 的每个列表
    for policy_idx, nations_list in enumerate(countries_visa_policy):
        # 遍历每个国家名称
        for nation_with_policy in nations_list:
            # 检查国家是否在 DataFrame 的列中
            if nation_with_policy in G.columns:
                # 更新 DataFrame 中对应国家的互免签证关系
                G.loc[nation_with_policy, country] = policy_idx + 1  # 1: visa free, 2: visa on arrival, 3: eVisa
    #G.to_csv(f'visa_G_{date[:4]}.csv', index=True)
    return G

# %% [markdown]
# # Start crawling

# %%
index = 0 # 记录当前爬取的国家数量

# 爬取每个国家的免签数据并更新 DataFrame
for country, [citizen_name, official_country_name] in list(nations.items()):
    print(f"Fetching data for {country}...")
    countries_visa_policy = fetch_visa_free_countries(country, citizen_name)    # 其它国家对country的免签政策, 失败为0
    
    # 如果爬取失败, countries_visa_policy == 0
    if countries_visa_policy == 0:
        break

    G = update_matrix(country, countries_visa_policy, G=G)
    # 等待一会儿以避免过多请求
    time.sleep(random.uniform(1, 3))

    index += 1  # 爬取成功+1
    if index == 57:
        print("成功爬取完成57个国家的数据")

# 保存 DataFrame 为 CSV 文件(在update_matrix这个函数中已保存)
G.to_csv(f'visa_G_{str(date)[:4]}.csv', index=True)
print(f"Visa matrix saved to visa_G_{str(date)[:4]}.csv")

# 查看结果
# print(G.head())
# Out:
# Fetching data for Afghanistan...
# 请求Afghanistan成功
# 正在处理第 1 个表格...
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa on arrival
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa
# Bhutan | Visa required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa required
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | eVisa
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | eVisa / Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa required
# Iran | Visa required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | Visa required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | eVisa
# Laos | Visa required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa required
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | eVisa
# Romania | Visa required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visitor Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa required
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa required
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# Eritrea(outsideAsmara) | Travel permit required
# Ascension Island | eVisa
# Saint Helena | eVisa
# Tristan da Cunha | Visa required
# Sahrawi Arab Democratic Republic(Western Sahara controlled territory) | Unknown
# Somaliland | Visa on arrival
# Visitor to | Visa requirement
# Hong Kong | Visa required
# IndiaPAP/RAP | PAP/RAP required
# Macau | Visa on arrival
# North KoreaoutsidePyongyang | Special permit required
# Taiwan | Visa required
# Gorno-Badakhshan Autonomous Province | Special permits required
# Tibet Autonomous Region | Travel permit required
# Korean Demilitarized Zone | Restricted zone.
# UNDOF ZoneandGhajar | Restricted zone.
# Visitor to | Visa requirement
# Anguilla | Visa required
# Aruba | Visa required
# Bermuda | Visa required
# Bonaire,St. EustatiusandSaba | Visa required
# British Virgin Islands | Visa required
# Cayman Islands | Visa required
# Curacao | Visa required
# French Guiana | Visa required
# French West Indies | Visa required
# Montserrat | Visa required
# Puerto Rico | Visa required
# Sint Maarten | Visa required
# Turks and Caicos Islands | Visa required
# U.S. Virgin Islands | Visa required
# Visitor to | Visa requirement
# Abkhazia | Visa required
# Mount Athos | Special permit required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access permit required
# Gibraltar | Visa required
# Jan Mayen | Permit required
# Kosovo | Visa required
# Artsakh | Visa required
# South Ossetia | Visa required
# Transnistria | Visa required
# Visitor to | Visa requirement
# American Samoa | Visa required
# Ashmore and Cartier Islands | Authoristion required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# French Polynesia | Visa required
# Guam | Visa required
# Niue | Visa on arrival
# Pitcairn Islands | Visa not required
# United States Minor Outlying Islands | Special permit required
# Visitor to | Visa requirement
# Falkland Islands | Visa required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica |
# Fetching data for Armenia...
# 请求Armenia成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa not required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Visa not required
# Argentina | Visa not required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Admission refused
# Bahamas | Visa not required
# Bahrain | Visa required
# Bangladesh | Visa on arrival
# Barbados | Visa not required
# Belarus | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa not required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist Card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Visa
# Indonesia | Visa not required
# Iran | Visa not required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa on arrival
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa not required
# Kenya | Visa required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa on arrival
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa not required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa not required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | eVisa
# Romania | Visa required
# Russia | Visa not required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa on arrival
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | eVisa
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa not required
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | eVisa
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa not required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa not required
# Uzbekistan | Visa not required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | eVisa
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa / Visa on arrival
# Fetching data for Australia...
# 请求Australia成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa not required
# Algeria | Visa required
# Andorra | Visa not required
# Angola | eVisa
# Antigua and Barbuda | Visa not required
# Argentina | Visa not required
# Armenia | Visa not required
# Austria | Visa not required
# Azerbaijan | eVisa
# Bahamas | Visa not required
# Bahrain | eVisa / Visa on arrival
# Bangladesh | Visa on arrival
# Barbados | Visa not required
# Belarus | Visa not required
# Belgium | Visa not required
# Belize | Visa not required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa required
# Bolivia | Visa not required
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa not required
# Brazil | eVisa
# Brunei | Visa on arrival
# Bulgaria | Visa not required
# Burkina Faso | Visa on arrival
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa not required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa not required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa not required
# Côte d'Ivoire | eVisa
# Croatia | Visa not required
# Cuba | Tourist Card required
# Cyprus | Visa not required
# Czech Republic | Visa not required
# Denmark | Visa not required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa not required
# Ecuador | Visa not required
# Egypt | eVisa / Visa on arrival
# El Salvador | Visa not required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa not required
# Eswatini | Visa not required
# Ethiopia | eVisa / Visa on arrival
# Fiji | Visa not required
# Finland | Visa not required
# France | Visa not required
# Gabon | eVisa / Visa on arrival
# Gambia | Visa not required
# Georgia | Visa not required
# Germany | Visa not required
# Ghana | Visa required
# Greece | Visa not required
# Grenada | Visa not required
# Guatemala | Visa not required
# Guinea | Visa required
# Guinea-Bissau | eVisa / Visa on arrival
# Guyana | Visa not required
# Haiti | Visa not required
# Honduras | Visa not required
# Hungary | Visa not required
# Iceland | Visa not required
# India | e-Visa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa not required
# Israel | Visa not required
# Italy | Visa not required
# Jamaica | Visa not required
# Japan | Visa not required
# Jordan | Visa on arrival
# Kazakhstan | Visa not required
# Kenya | eVisa / Visa on arrival
# Kiribati | Visa not required
# North Korea | Visa required
# South Korea | Visa not required
# Kuwait | eVisa / Visa on arrival
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa not required
# Lebanon | Visa on arrival
# Lesotho | Visa not required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa not required
# Lithuania | Visa not required
# Luxembourg | Visa not required
# Macedonia | Visa not required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa not required
# Marshall Islands | Visa on arrival
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa not required
# Micronesia | Visa not required
# Moldova | Visa not required
# Monaco | Visa not required
# Mongolia | Visa required
# Montenegro | Visa not required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa not required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa not required
# New Zealand | Freedom of movement
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa not required
# Oman | eVisa
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | eVisa / Free visa on arrival
# Paraguay | Visa on arrival
# Peru | Visa not required
# Philippines | Visa not required
# Poland | Visa not required
# Portugal | Visa not required
# Qatar | Visa not required
# Romania | Visa not required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa not required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa not required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa on arrival
# Serbia | Visa not required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa not required
# Slovenia | Visa not required
# Solomon Islands | Visitor's permit on arrival
# Somalia | Visa on arrival
# South Africa | Visa not required
# South Sudan | Visa required
# Spain | Visa not required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa not required
# Switzerland | Visa not required
# Syria | Visa required
# Tajikistan | Visa on arrival
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa on arrival
# Trinidad and Tobago | Visa on arrival
# Tunisia | Visa not required
# Turkey | eVisa
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | eVisa
# United Arab Emirates | Visa on arrival
# United KingdomandCrown dependencies | Visa not required
# United States | Visa Waiver Program
# Uruguay | Visa not required
# Uzbekistan | eVisa
# Vanuatu | Visa not required
# Vatican City | Visa not required
# Venezuela | Visa not required
# Vietnam | eVisa
# Yemen | Visa required
# Zambia | eVisa / Visa on arrival
# Zimbabwe | eVisa / Visa on arrival
# 正在处理第 2 个表格...
# Abkhazia | Visa required
# Kosovo | Visa not required
# Northern Cyprus | Visa not required
# Artsakh | Visa required
# Palestine | Visa not required
# Sahrawi Arab Democratic Republic |
# Somaliland | Visa on arrival
# South Ossetia | Visa not required
# Taiwan | Visa not required
# Transnistria | Visa not required
# 正在处理第 3 个表格...
# Hong Kong | Visa not required
# Macau | Visa not required
# Faroe Islands | Visa not required
# Greenland | Visa not required
# French Guiana | Visa not required
# French Polynesia | Visa not required
# French West Indies | Visa not required
# Mayotte | Visa not required
# New Caledonia | Visa not required
# Réunion | Visa not required
# Saint Pierre and Miquelon | Visa not required
# Wallis and Futuna | Visa not required
# Aruba | Visa not required
# Caribbean Netherlands | Visa not required
# Curaçao | Visa not required
# Sint Maarten | Visa not required
# Cook Islands | Visa not required
# Niue | Visa not required
# Tokelau | Visa required
# Akrotiri and Dhekelia | Visa not required
# Anguilla | Visa not required
# Bermuda | Visa not required
# British Indian Ocean Territory | Special permit required
# British Virgin Islands | Visa not required
# Cayman Islands | Visa not required
# Falkland Islands | Visa not required
# Gibraltar | Visa not required
# Montserrat | Visa not required
# Pitcairn Islands | Visa not required
# Ascension Island | eVisa
# Saint Helena | Visitor's Pass required
# Tristan da Cunha | Permission required
# South Georgia and the South Sandwich Islands | Permit required
# Turks and Caicos Islands | Visa not required
# American Samoa | Electronic authorization
# Guam | Visa not required
# Northern Mariana Islands | Visa not required
# Puerto Rico | Visa not required
# U.S. Virgin Islands | Visa not required
# 正在处理第 4 个表格...
# BrestandGrodno | Visa not required
# ChinaHainan | Visa on arrival
# ChinaTibet Autonomous Region | TTP required
# Crimea | Visa required
# EcuadorGalápagos | Pre-registration required
# EritreaoutsideAsmara | Travel permit required
# GreeceMount Athos | Special permit required
# IndiaPAP/RAP | PAP/RAP required
# IranKish Island | Visa not required
# Iraqi Kurdistan | Visa on arrival
# FijiLau Province | Special permission required
# FranceClipperton Island | Special permit required
# Kazakhstan | Special permission required
# North KoreaoutsidePyongyang | Special permit required
# MalaysiaSabahandSarawak | Visa not required
# MaldivesoutsideMalé | Permission required
# NorwayJan Mayen | Permit required
# SvalbardofNorway | Visa not Required
# Novorossiya | Restricted area
# Russia | Special authorization required
# SudanoutsideKhartoum | Travel permit required
# SudanDarfur | Travel permit required
# TajikistanGorno-Badakhshan Autonomous Province | OIVR permit required
# UN Buffer Zone in Cyprus | Access Permit required
# Korean Demilitarized Zone | Restricted zone.
# UNDOF ZoneandGhajar | Restricted zone.
# United States Minor Outlying Islands | Special permits required
# VenezuelaMargarita Island | Visa not required
# VietnamPhú Quốc | Visa not required
# YemenoutsideSana’aorAden | Special permission required
# 正在处理第 5 个表格...
# Destination | Number of Australian visitors
# American Samoa[note 1] | 775
# Angola | 702
# Antarctica[note 1] | 4,488
# Antigua and Barbuda[note 1] | 761
# Austria[note 2][note 3] | 143,000
# Azerbaijan[note 3] | 1,851
# Bahamas[note 4] | 3,858
# Barbados[note 2][note 3] | 2,301
# Belgium[note 3] | 43,276
# Bhutan[note 1] | 2,249
# Bolivia[note 3] | 11,044
# Bosnia and Herzegovina[note 1] | 8,632
# Botswana | 15,607
# Brazil[note 1] | 33,862
# Brunei[note 5] | 18,845
# Cambodia[note 3] | 146,806
# Canada[note 1] | 392,364
# Cayman Islands[note 1][note 6] | 1,303
# Chile[note 3] | 50,968
# China[note 3] | 673,200
# Colombia | 13,356
# Congo[note 7] | 69
# Cook Islands[note 1] | 25,912
# Costa Rica[note 1] | 12,320
# Croatia[note 1] | 186,323
# Cyprus[note 1] | 14,655
# Dominica | 437
# Dominican Republic[note 1] | 2,723
# Ecuador[note 8] | 13,686
# Estonia[note 2][note 1] | 7,431
# Fiji[note 1] | 365,689
# Finland | 26,959
# France | 1,266,509
# French Polynesia[note 1] | 7,363
# Georgia[note 1] | 4,611
# Germany[note 3] | 314,014
# Greece | 183,165
# Guatemala[note 8] | 17,206
# Guam[note 1][note 6] | 2,255
# Hong Kong[note 1] | 567,881
# Hungary[note 2][note 3] | 41,231
# Indonesia[note 3] | 1,302,291
# India[note 1] | 324,243
# Israel[note 1] | 39,900
# Italy[note 3] | 884,000
# Jamaica[note 1] | 2,574
# Japan[note 1] | 495,100
# Jordan[note 3] | 21,857
# Kazakhstan[note 1] | 4,225
# Kiribati[note 1] | 1,097
# Kyrgyzstan[note 1] | 2,500
# Laos[note 1] | 20,886
# Latvia[note 2][note 1] | 7,421
# Lebanon[note 3] | 72,743
# Luxembourg[note 3][note 2] | 3,525
# Macau[note 1] | 88,988
# Macedonia[note 3][note 2] | 5,557
# Madagascar | 1,098
# Malaysia[note 1] | 351,232
# Malawi[note 9] | 10,250
# Maldives[note 1] | 27,360
# Mali[note 8] | 860
# Malta[note 1] | 35,875
# Marshall Islands[note 1] | 234
# Mauritius[note 1] | 21,271
# Mexico[note 1][note 6] | 84,225
# Micronesia[note 1] | 942
# Mongolia[note 1] | 6,689
# Montenegro[note 2][note 3] | 6,103
# Myanmar[note 3] | 34,010
# Namibia | 7,888
# Nauru[note 1] | 2,171
# Nepal | 18,619
# Netherlands[note 8] | 188,000
# New Caledonia[note 1] | 23,705
# New Zealand[note 1] | 1,472,160
# Niue[note 1] | 951
# Oman[note 1] | 17,441
# Pakistan[note 9] | 13,200
# Palau[note 1] | 661
# Panama | 4,349
# Papua New Guinea[note 1] | 70,112
# Peru[note 1] | 41,810
# Philippines[note 1] | 259,433
# Qatar[note 1] | 42,765
# Romania[note 3] | 16,978
# Russia[note 1] | 49,259
# Samoa[note 1] | 32,431
# Serbia[note 1][note 2] | 13,559
# Seychelles | 1,661
# Singapore[note 1] | 1,081,987
# Slovakia[note 3][note 2] | 7,888
# Slovenia[note 1][note 2] | 34,205
# Solomon Islands[note 1] | 10,161
# South Africa | 99,205
# South Korea[note 1] | 150,408
# Sri Lanka[note 1] | 81,281
# Suriname[note 1] | 453
# Swaziland[note 3] | 3,132
# Taiwan[note 1] | 107,157
# Tanzania[note 3] | 15,356
# Tonga[note 1] | 12,924
# Thailand[note 1] | 817,091
# Timor-Leste[note 1][note 10] | 15,186
# Turkey[note 1] | 77,153
# Tuvalu[note 1] | 320
# Uganda[note 4] | 7,842
# Ukraine[note 1] | 5,743
# United Arab Emirates[note 1] | 279,000
# United Kingdom[note 1] | 831,000
# United States[note 1][note 11] | 1,576,901
# Vanuatu[note 1] | 57,384
# Vietnam[note 1] | 370,438
# Zambia | 12,363
# Zimbabwe | 22,016
# Fetching data for Azerbaijan...
# 请求Azerbaijan成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa not required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Visa not required
# Argentina | Visa required
# Armenia | Visa not required
# Australia | Visa required
# Austria | Visa required
# Bahamas | Visa not required
# Bahrain | eVisa
# Bangladesh | Visa on arrival
# Barbados | Visa not required
# Belarus | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Visa
# Indonesia | Visa not required
# Iran | Visa not required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa on arrival
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa not required
# Kenya | Visa required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa on arrival
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa not required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa on arrival
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa not required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa not required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa not required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa not required
# Romania | Visa required
# Russia | Visa not required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa not required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa not required
# Tanzania | Visa required
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa not required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa not required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa not required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | eVisa
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa / Visa on arrival
# Fetching data for Bahrain...
# 请求Bahrain成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required (temporary)
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | eVisa / Visa on arrival
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | eVisa / Visa on arrival
# Bahamas | Visa not required
# Bangladesh | Visa on arrival
# Barbados | Visa required
# Belarus | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa not required
# Brazil | Visa required
# Brunei | Visa on arrival
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | eVisa
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa not required
# Ecuador | Visa not required
# Egypt | Visa not required
# El Salvador | Visa not required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa / Visa on arrival
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa not required
# Guinea | Visa required
# Guinea-Bissau | eVisa / Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa not required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa on arrival
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa not required
# Kazakhstan | Visa required
# Kenya | eVisa / Visa on arrival
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa not required
# Kuwait | Visa not required
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa not required
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa not required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa not required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa not required
# Romania | Visa required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa not required
# Senegal | Visa on arrival
# Serbia | Visa not required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | eVisa
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa not required
# Turkey | eVisa
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | eVisa
# United Arab Emirates | Visa not required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa on arrival
# Zambia | eVisa
# Zimbabwe | eVisa / Visa on arrival
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# Kosovo | No Information
# EritreaoutsideAsmara | Travel permit required
# Mayotte | Visa required
# Réunion | Visa required
# Ascension Island | eVisa
# Saint Helena | eVisa
# Sahrawi Arab Democratic Republic |
# Somaliland | Visa on arrival
# SudanoutsideKhartoum | Travel permit required
# Darfur | Travel permit required
# Visitor to | Visa requirement
# Hainan | Visa not required
# IndiaPAP/RAP | PAP/RAP required
# Kazakhstanclosed cities | Special permission required
# Kish Island | Visa not required
# SabahandSarawak | Visa not required
# North KoreaoutsidePyongyang | Special permit required
# Palestine | Visa not required
# Taiwan | Electronic Entry Visa
# Gorno-Badakhshan Autonomous Province | OIVR permit required
# Tibet Autonomous Region | TTP required
# Turkmenistanclosed cities | Special permit required
# Korean Demilitarized Zone | Restricted zone.
# UNDOF ZoneandGhajar | Restricted zone.
# Visitor to | Visa requirement
# Anguilla | Visa required
# Aruba | Visa required
# Bermuda | Visa required
# Bonaire,St. EustatiusandSaba | Visa required
# British Virgin Islands | Visa required
# San AndrésandLeticia | Tourist Card on arrival
# Cayman Islands | Visa required
# Curacao | Visa required
# French Guiana | Visa required
# French West Indies | Visa required
# Greenland | Visa required
# Margarita Island | Visa required
# Montserrat | Visa required
# Puerto Rico | Visa required
# Saint Pierre and Miquelon | Visa required
# Sint Maarten | Visa required
# Turks and Caicos Islands | Visa not required
# U.S. Virgin Islands | Visa required
# Visitor to | Visa requirement
# Mount Athos | Special permit required
# BrestandGrodno | Visa not required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access Permit required
# Faroe Islands | Visa required
# Gibraltar | Visa required
# Guernsey | Visa required
# Isle of Man | Visa required
# Jersey | Visa required
# Artsakh | Visa required
# Visitor to | Visa requirement
# American Samoa | Entry permit required
# Ashmore and Cartier Islands | Special authorisation required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# Lau Province | Special permission required
# French Polynesia | Visa required
# Guam | Visa required
# New Caledonia | Visa required
# Niue | Visa on arrival
# Northern Mariana Islands | Visa required
# Pitcairn Islands | Visa required
# United States Minor Outlying Islands | Special permits required
# Wallis and Futuna | Visa required
# Visitor to | Visa requirement
# Galápagos | Pre-registration required
# Visitor to | Visa requirement
# Falkland Islands | Visa required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica |
# Fetching data for Bangladesh...
# 请求Bangladesh成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa not required
# Bahrain | Visa required
# Barbados | Visa not required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa not required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa required
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa not required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa not required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa not required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa not required
# Iran | Visa required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa not required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | eVisa / Visa on arrival
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | eVisa
# Laos | Visa required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa not required
# Liberia | Visa required
# Libya | Admission refused
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | eVisa
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa required
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | eVisa
# Romania | Visa required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Admission refused
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa required
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa not required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa
# Fetching data for Belarus...
# 请求Belarus成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Visa not required
# Argentina | Visa not required
# Armenia | Visa not required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Visa not required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa on arrival
# Barbados | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa not required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa not required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | eVisa
# Croatia | Visa required
# Cuba | Visa not required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | e-Visa
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa not required
# Italy | Visa required
# Jamaica | Visa on arrival
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa not required
# Kenya | eVisa / Visa on arrival
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa on arrival
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa not required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa not required
# Monaco | Visa required
# Mongolia | Visa not required
# Montenegro | Visa not required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa not required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa not required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa not required
# Romania | Visa required
# Russia | Visa not required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa not required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa not required
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa not required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa not required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa not required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa not required
# Vietnam | Visa not required
# Yemen | Visa required
# Zambia | eVisa / Visa on arrival
# Zimbabwe | eVisa / Visa on arrival
# 正在处理第 2 个表格...
# Abkhazia | Visa not required
# Mount Athos | Visa required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Visa required
# Gibraltar | Visa required
# Jan Mayen | Visa required
# Kosovo | Visa required
# Nagorno-Karabakh Republic | Visa not required
# South Ossetia | Visa not required
# Transnistria | Visa not required
# 正在处理第 3 个表格...
# British Indian Ocean Territory | Visa required
# Eritrea(outsideAsmara) | Visa required
# Ascension Island | eVisa
# Saint Helena | eVisa
# Tristan da Cunha | Visa required
# Sahrawi Arab Democratic Republic(Western Sahara controlled territory) | Undefined visa regime
# Somaliland | Visa required
# 正在处理第 4 个表格...
# ...
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | Visa not required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa not required
# New Zealand | Visa not required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa not required
# Oman | eVisa
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | eVisa / Free visa on arrival
# Paraguay | Visa not required
# Peru | Visa not required
# Philippines | Visa not required
# Poland | Visa not required
# Portugal | Visa not required
# Qatar | Visa not required
# Romania | Visa not required
# Russia | Visa not required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa not required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa not required
# São Tomé and Príncipe | Visa not required
# Saudi Arabia | Visa required
# Senegal | Visa not required
# Serbia | Visa not required
# Seychelles | Visitor's Permit on arrival
# Singapore | Visa not required
# Sierra Leone | Visa required
# Slovakia | Visa not required
# Slovenia | Visa not required
# Solomon Islands | Visitor's permit on arrival
# Somalia | Travel banned
# South Africa | Visa not required
# South Sudan | Visa required
# Spain | Visa not required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa not required
# Sweden | Visa not required
# Switzerland | Visa not required
# Syria | Travel banned
# Tajikistan | eVisa
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa on arrival
# Trinidad and Tobago | Visa not required
# Tunisia | Visa not required
# Turkey | Visa not required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa not required
# United Arab Emirates | Free visa on arrival
# United Kingdom | Visa not required
# United States | Visa Waiver Program
# Uruguay | Visa not required
# Uzbekistan | Visa not required
# Vanuatu | Visa not required
# Vatican City | Visa not required
# Venezuela | Visa not required
# Vietnam | Visa not required
# Yemen | Travel banned
# Zambia | eVisa / Visa on arrival
# Zimbabwe | eVisa / Visa on arrival
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# Abkhazia | Visa required
# Mount Athos | Special permit required
# ATO zone | Special permission required
# BrestandGrodno | Visa not required
# Crimea | Visa not required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access Permit required
# Faroe Islands | Visa not required
# Gibraltar | Visa not required
# Guernsey | Visa not required
# Isle of Man | Visa not required
# Jan Mayen | Permit required
# Jersey | Visa not required
# Kosovo | Visa not required
# Nagorno-Karabakh Republic | Visa required
# Russia | Special authorization required
# South Ossetia | Visa not required
# Transnistria | Visa not required
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# EritreaoutsideAsmara | Travel permit required
# Mayotte | Visa not required
# Réunion | Visa not required
# Ascension Island | eVisa
# Saint Helena | Visitor's Pass required
# Tristan da Cunha | Permission required
# Sahrawi Arab Democratic Republic |
# Somaliland | Travel banned
# Sudan | Travel permit required
# Darfur | Travel permit required
# Visitor to | Visa requirement
# Hainan | Visa on arrival
# North KoreaGaesung Industrial Complex | Admission refused
# Hong Kong | Visa not required
# IndiaPAP/RAP | PAP/RAP required
# Kazakhstan | Special permission required
# Kish Island | Visa not required
# Macao | Visa not required
# SabahandSarawak | Visa not required
# Maldives | Permission required
# North KoreaoutsidePyongyang | Admission refused
# Palestine | Visa not required
# Taiwan | Visa not required
# Gorno-Badakhshan Autonomous Province | OIVR permit required
# Tibet Autonomous Region | TTP required
# Turkmenistan | Special permit required
# Korean Demilitarized Zone | Special permission required
# UNDOF ZoneandGhajar | Restricted zone.
# Yemen | Travel banned
# Visitor to | Visa requirement
# Anguilla | Visa not required
# Aruba | Visa not required
# Bermuda | Visa not required
# Bonaire,St. EustatiusandSaba | Visa not required
# British Virgin Islands | Visa not required
# San AndrésandLeticia | Tourist Card on arrival
# Cayman Islands | Visa required
# Curacao | Visa not required
# French Guiana | Visa not required
# French West Indies | Visa not required
# Greenland | Visa not required
# Margarita Island | Visa not required
# Montserrat | Visa not required
# Puerto Rico | Visa not required
# Saint Pierre and Miquelon | Visa not required
# Sint Maarten | Visa not required
# Turks and Caicos Islands | Visa not required
# U.S. Virgin Islands | Visa not required
# Visitor to | Visa requirement
# American Samoa | Electronic authorization
# Ashmore and Cartier Islands | Special authorisation required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# Lau Province | Special permission required
# French Polynesia | Visa not required
# Guam | Visa not required
# New Caledonia | Visa not required
# Niue | Visa on arrival
# Northern Mariana Islands | Visa not required
# Pitcairn Islands | Visa not required
# United States Minor Outlying Islands | Special permits required
# Wallis and Futuna | Visa not required
# Visitor to | Visa requirement
# Galápagos | Pre-registration required
# Visitor to | Visa requirement
# Falkland Islands | Visa not required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica | Special permits required
# Fetching data for Syria...
# 请求Syria成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa
# Bhutan | Visa required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa required
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | eVisa
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | eVisa / Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa required
# Iran | Visa not required (Conditional)
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | Visa required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | eVisa
# Laos | Visa required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Admission refused
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa not required
# Maldives | free Visa on arrival
# Mali | Admission refused
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa required
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa required
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | eVisa
# Romania | Visa required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | evisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa required
# Samoa | Visitor's Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa required
# Sudan | Visa not required (Conditional)
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Tajikistan | Visa required
# Tanzania | Visa required
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Admission refused
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | free visa on arrival
# Zambia | evisa
# Zimbabwe | evisa
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# Kosovo | Visa required
# Fetching data for Bhutan...
# 请求Bhutan成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | eVisa / Visa on arrival
# Australiaand territories | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa not required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | eVisa / Visa on arrival
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | eVisa / Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist Card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | eVisa
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa on arrival
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Eswatini | Visa required
# Ethiopia | eVisa
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa not required
# Georgia | eVisa
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hong Kong | Visa not required
# Hungary | Visa required
# Iceland | Visa required
# India | Freedom of movement
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa required
# Kenya | eVisa / Visa on arrival
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | eVisa / Visa on arrival
# Kyrgyzstan | eVisa
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa on arrival
# Lesotho | eVisa
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | eVisa
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealandand territories | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | eVisa
# Romania | Visa required
# Russia | Visa required
# Rwanda | eVisa / Visa on arrival
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa on arrival
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa on arrival
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | eVisa / Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | eVisa / Visa on arrival
# Thailand | Visa on arrival
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | eVisa / Visa on arrival
# Ukraine | eVisa
# United Arab Emirates | Visa required
# United Kingdomexcluding some Overseas territories | Visa required
# United Statesand territories | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | eVisa / Visa on arrival
# Zimbabwe | eVisa / Visa on arrival
# 成功爬取完成57个国家的数据
# Visa matrix saved to visa_G_2019.csv

# %% [markdown]
# # If fail, start again from the checkpoint
#
# 失败的原因是被wiki关闭了访问, 可以更换网络节点, 点击下方自动从断点开始

# %%
print(countries_visa_policy)
print(index)
print(list(nations.items())[index:])
# Out:
# 0
# 33
# [('Myanmar', ['Burmese', 'Myanmar']), ('Nepal', ['Nepalese', 'Nepal']), ('NewZealand', ['New_Zealand', 'New Zealand']), ('Oman', ['Omani', 'Oman']), ('Pakistan', ['Pakistani', 'Pakistan']), ('PapuaNewGuinea', ['Papua_New_Guinean', 'Papua New Guinea']), ('Philippines', ['Filipino', 'Philippines']), ('Qatar', ['Qatari', 'Qatar']), ('Russia', ['Russian', 'Russia']), ('SaudiArabia', ['Saudi', 'Saudi Arabia']), ('Singapore', ['Singaporean', 'Singapore']), ('SriLanka', ['Sri_Lankan', 'Sri Lanka']), ('Tajikistan', ['Tajikistani', 'Tajikistan']), ('Thailand', ['Thai', 'Thailand']), ('Tonga', ['Tongan', 'Tonga']), ('Turkey', ['Turkish', 'Turkey']), ('UnitedArabEmirates', ['Emirati', 'United Arab Emirates']), ('Uzbekistan', ['Uzbekistani', 'Uzbekistan']), ('Vanuatu', ['Vanuatuan', 'Vanuatu']), ('Vietnam', ['Vietnamese', 'Vietnam']), ('Yemen', ['Yemeni', 'Yemen']), ('SouthKorea', ['South_Korean', 'South Korea']), ('Syria', ['Syrian', 'Syria']), ('Bhutan', ['Bhutanese', 'Bhutan'])]

# %%
# 从checkpoint继续爬取
for country, [citizen_name, official_country_name] in list(nations.items())[index:]:
    print(f"Fetching data for {country}...")
    countries_visa_policy = fetch_visa_free_countries(country, citizen_name)    # 其它国家对country的免签政策，state记录爬取是否成功，成功为1，失败为0
    
    # 如果爬取失败, checkpoint > 0
    if countries_visa_policy == 0:
        break
    
    G = update_matrix(country, countries_visa_policy, G=G)

    # 等待一会儿以避免过多请求
    time.sleep(random.uniform(1, 3))
    
    index += 1 # 爬取成功的国家数量，若爬取失败，index可以作为断点继续开始国家的索引
    if index == 57:
        print("成功爬取完成57个国家的数据")
# 保存 DataFrame 为 CSV 文件
G.to_csv(f'visa_G_{str(date)[:4]}.csv', index=True)
print(f"Visa matrix saved to visa_G_{str(date)[:4]}.csv")

# 查看结果
# print(G.head())
# Out:
# Fetching data for Myanmar...
# 请求Myanmar成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa de facto required
# Angola | Visa required
# Antigua and Barbuda | Visa required
# Argentina | Visa required
# Armenia | Visa on arrival
# Australiaand territories | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa not required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Cote d'Ivoire !Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist Card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | Visa required
# Gambia | Visa required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hong Kong | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Tourist Visa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa on arrival
# Kyrgyzstan | Visa required
# Laos | Visa not required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealandand territories | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa required
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdomexcluding some Overseas territories | Visa required
# United Statesand territories | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa not required
# Yemen | Visa required
# Zambia | Visa on arrival
# Zimbabwe | Visa required
# Fetching data for Nepal...
# 请求Nepal成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | eVisa
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa not required
# Georgia | Visa Required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Freedom of movement
# Indonesia | Visa not required
# Iran | Visa required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Electronic Visa
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa not required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa not required
# Serbia | Visa required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Electronic Travel Authorization
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa on arrival
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa
# Fetching data for NewZealand...
# 请求NewZealand成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa not required
# Algeria | Visa required
# Andorra | Visa not required
# Angola | Visa required
# Antigua and Barbuda | Visa not required
# Argentina | Visa not required
# Armenia | Visa on arrival
# Australia | Visa not required
# Austria | Visa not required
# Azerbaijan | eVisa
# Bahamas | Visa not required
# Bahrain | Visa on arrival
# Bangladesh | Visa on arrival
# Barbados | Visa not required
# Belarus | Visa not required
# Belgium | Visa not required
# Belize | Visa not required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa not required
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa not required
# Brazil | Visa not required
# Brunei | Visa not required
# Bulgaria | Visa not required
# Burkina Faso | Visa on arrival
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa not required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa not required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa not required
# Cote d'Ivoire !Côte d'Ivoire | eVisa
# Croatia | Visa not required
# Cuba | Visa required !Tourist Card required
# Cyprus | Visa not required
# Czech Republic | Visa not required
# Denmark | Visa not required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa not required
# Ecuador | Visa not required
# Egypt | Visa on arrival
# El Salvador | Visa not required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa not required
# Ethiopia | Visa on arrival
# Fiji | Visa not required
# Finland | Visa not required
# France | Visa not required
# Gabon | e-Visa
# Gambia | Visa not required
# Georgia | Visa not required
# Germany | Visa not required
# Ghana | Visa required
# Greece | Visa not required
# Grenada | Visa not required
# Guatemala | Visa not required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa not required
# Haiti | Visa not required
# Honduras | Visa not required
# Hungary | Visa not required
# Iceland | Visa not required
# India | eVisa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa not required
# Israel | Visa not required
# Italy | Visa not required
# Jamaica | Visa not required
# Japan | Visa not required
# Jordan | Visa on arrival
# Kazakhstan | Visa not required
# Kenya | eVisa
# Kiribati | Visa not required
# North Korea | Visa required
# South Korea | Visa not required
# Kuwait | eVisa
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa not required
# Lebanon | Visa on arrival
# Lesotho | Visa not required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa not required
# Lithuania | Visa not required
# Luxembourg | Visa not required
# Macedonia | Visa not required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa not required
# Marshall Islands | Visa on arrival
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa not required
# Micronesia | Visa not required
# Moldova | Visa not required
# Monaco | Visa not required
# Mongolia | Visa required
# Montenegro | Visa not required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa not required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa not required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa not required
# Oman | Visa not required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa on arrival
# Paraguay | Visa on arrival
# Peru | Visa not required
# Philippines | Visa not required
# Poland | Visa not required
# Portugal | Visa not required
# Qatar | Visa on arrival
# Romania | Visa not required
# Russia | Visa required
# Rwanda | Visa on arrival
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa not required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa not required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa not required
# Serbia | Visa not required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa not required
# Slovenia | Visa not required
# Solomon Islands | Visa on arrival !Visitor's permit on arrival
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa not required
# Sri Lanka | Electronic Travel Authorization
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa not required
# Sweden | Visa not required
# Switzerland | Visa not required
# Syria | Visa required
# Tajikistan | Visa on arrival
# Tanzania | Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa on arrival
# Trinidad and Tobago | Visa on arrival
# Tunisia | Visa not required
# Turkey | Visa not required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa on arrival
# United Arab Emirates | Visa on arrival
# United Kingdom | Visa not required
# United States | Visa not required !Visa Waiver Program
# Uruguay | Visa not required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa not required
# Venezuela | Visa not required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | Visa on arrival
# Zimbabwe | Visa on arrival
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# Abkhazia | Visa required
# Mount Athos | Special permit required
# Belovezhskaya Pushcha National Park | Visa not required
# Crimea | Visa required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access Permit required
# Faroe Islands | Visa not required
# Gibraltar | Visa not required
# Guernsey | Visa not required
# Isle of Man | Visa not required
# Jan Mayen | Permit required
# Jersey | Visa not required
# Kosovo | Visa not required
# Nagorno-Karabakh Republic | Visa required
# Novorossiya | Restricted area
# Russia | Special authorization required
# South Ossetia | Visa not required
# Transnistria | Visa not required
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# EritreaoutsideAsmara | Travel permit required
# Ascension Island | Entry Permit required
# Saint Helena | Visitor's Pass required
# Tristan da Cunha | Permission required
# Sahrawi Arab Democratic Republic |
# Somaliland | Visa on arrival
# Sudan | Travel permit required
# Darfur | Travel permit required
# Visitor to | Visa requirement
# Hainan | Visa on arrival
# Hong Kong | Visa not required
# IndiaPAP/RAP | PAP/RAP required
# Kazakhstan | Special permission required
# Kish Island | Visa not required
# Macao | Visa not required
# SabahandSarawak | Visa not required
# Maldives | Permission required
# Palestine | Visa not required
# Taiwan | Visa not required
# Gorno-Badakhshan Autonomous Province | OIVR permit required
# Tibet Autonomous Region | TTP required
# Korean Demilitarized Zone | Restricted zone.
# UNDOF ZoneandGhajar | Restricted zone.
# Phú Quốc | Visa not required
# Yemen | Special permission required
# Visitor to | Visa requirement
# Anguilla | Visa not required
# Aruba | Visa not required
# Bermuda | Visa not required
# Bonaire,St. EustatiusandSaba | Visa not required
# British Virgin Islands | Visa not required
# Cayman Islands | Visa not required
# Curacao | Visa not required
# French Guiana | Visa not required
# French West Indies | Visa not required
# Greenland | Visa not required
# Margarita Island | Visa not required
# Montserrat | Visa not required
# Puerto Rico | Visa not required
# Sint Maarten | Visa not required
# Turks and Caicos Islands | Visa not required
# U.S. Virgin Islands | Visa not required
# Visitor to | Visa requirement
# American Samoa | Entry permit required
# Ashmore and Cartier Islands | Special authorisation required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# Guam | Visa not required
# Lau Province | Special permission required
# French Polynesia | Visa not required
# Niue | Visa on arrival
# Northern Mariana Islands | Visa not required
# Pitcairn Islands | Visa not required
# United States Minor Outlying Islands | Special permits required
# Visitor to | Visa requirement
# Galápagos | Pre-registration required
# Visitor to | Visa requirement
# Falkland Islands | Visa not required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica |
# 正在处理第 3 个表格...
# Destination | Number of New Zealand visitors
# American Samoa | 3,580
# Angola[note 1] | 184
# Antarctica[note 2] | 430
# Antigua and Barbuda[note 2] | 240
# Australia[note 2] | 1,347,400
# Austria[note 3][note 2] | 19,900
# Azerbaijan | 520
# Belgium | 8,278
# Bahamas[note 4] | 758
# Bolivia[note 1] | 2,793
# Bosnia and Herzegovina[note 2] | 771
# Botswana | 2,956
# Brazil | 10,301
# Cambodia[note 2] | 24,797
# Canada[note 2] | 62,118
# Cayman Islands[note 2][note 5] | 499
# Chile[note 2] | 9,991
# China | 125,400
# Colombia | 2,325
# Congo[note 6] | 154
# Cook Islands[note 2] | 99,490
# Costa Rica[note 2] | 2,851
# Croatia[note 2] | 25,751
# Cyprus[note 2] | 389
# Dominica | 21
# Ecuador[note 1] | 2,304
# Fiji[note 2] | 163,836
# French Polynesia | 7,315
# Georgia[note 2] | 707
# Germany | 55,577
# Guatemala[note 1] | 2,617
# India | 45,171
# Indonesia | 86,609
# Israel[note 2] | 3,900
# Jamaica[note 2] | 404
# Japan | 49,402
# Jordan | 3,678
# Kazakhstan | 630
# Kiribati[note 1] | 395
# Laos | 4,798
# Lebanon[note 4] | 1,220
# Macau[note 2] | 13,731
# Macedonia | 457
# Madagascar | 117
# Malaysia | 60,846
# Malawi[note 7] | 1,589
# Maldives[note 2] | 2,087
# Mali[note 1] | 96
# Mauritius[note 2] | 939
# Micronesia | 285
# Montenegro[note 1][note 3] | 651
# Myanmar | 4,547
# Nepal | 2,610
# New Caledonia | 8,529
# Niue[note 7] | 2,690
# Oman[note 4] | 15,616
# Panama | 1,059
# Papua New Guinea[note 2] | 10,265
# Peru | 6,478
# Philippines | 20,579
# Russia | 6,369
# Samoa | 61,736
# Serbia[note 2][note 3] | 1,337
# Singapore[note 2] | 121,100
# Slovenia | 4,704
# Solomon Islands | 1,451
# South Africa | 19,436
# South Korea[note 2] | 31,623
# Sri Lanka[note 2] | 9,045
# Suriname | 25
# Taiwan[note 2] | 13,676
# Tanzania[note 4] | 3,033
# Tonga | 25,838
# Thailand[note 2] | 111,246
# Timor-Leste[note 1][note 8] | 896
# Turkey[note 2] | 15,287
# Tuvalu[note 9] | 133
# Ukraine[note 2] | 754
# United Kingdom | 207,000
# United States[note 10] | 336,645
# Vanuatu | 13,422
# Vietnam[note 2] | 42,588
# Zambia | 2,072
# Zimbabwe | 6,725
# Fetching data for Oman...
# 请求Oman成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa on arrival
# Australia | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | Visa on arrival
# Bahamas | Visa not required
# Bahrain | GCC !Visa not required
# Bangladesh | Visa on arrival
# Barbados | Visa required
# Belarus | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa not required
# Brazil | Visa required
# Brunei | Visa not required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa not required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Tourist Visa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa not required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa not required
# Kuwait | GCC !Visa not required
# Kyrgyzstan | Visa on arrival
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa not required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa not required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | GCC !Visa not required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | GCC !Visa not required
# Senegal | Visa on arrival
# Serbia | Visa not required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Electronic Travel Authorization
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa on arrival
# Tanzania | Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa not required
# Turkey | eVisa
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | GCC !Visa not required
# United Kingdom | Electronic Visa Waiver
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa on arrival
# Zambia | eVisa
# Zimbabwe | eVisa
# Fetching data for Pakistan...
# 请求Pakistan成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | eVisa
# Bahamas | Visa required
# Bahrain | eVisa
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa required
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# East Timor | Visa on arrival
# Ecuador | Visa required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa required
# Iran | Visa required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Ivory Coast | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa required
# Laos | Visa required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa required
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | eVisa
# Tanzania | Visa on arrival
# Thailand | Visa required
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa not required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa
# Fetching data for PapuaNewGuinea...
# 请求PapuaNewGuinea成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Visa not required
# Argentina | Visa required
# Armenia | Visa on arrival
# Australiaand territories | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa not required
# Bahrain | Visa required
# Bangladesh | Visa not required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa required
# Botswana | Visa not required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa not required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Cote d'Ivoire !Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist Card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Tourist card on arrival
# Ecuador | Visa not required
# Egypt | Visa on arrival
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa not required
# Finland | Visa required
# France | Visa required
# Gabon | Visa required
# Gambia | Visa not required
# Georgia | eVisa
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa not required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Tourist Visa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa not required
# Italy | Visa required
# Jamaica | Visa not required
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa required
# Kenya | Visa not required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa not required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa on arrival
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa on arrival
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealandand territories | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Paraguay | Visa required
# Peru | Visa not required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa on arrival
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa not required
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa on arrival
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa not required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa not required
# Thailand | Visa on arrival
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa on arrival
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdomexcluding some Overseas territories | Visa not required
# United Statesand territories | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | Visa on arrival
# Zimbabwe | Visa on arrival
# Fetching data for Philippines...
# 请求Philippines成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa on arrival
# Australia | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa not required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa not required
# Brunei | Visa not required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa not required
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa not required
# Côte d'Ivoire | eVisa
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa not required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa not required
# Georgia | eVisa
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | e-Tourist Visa
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa not required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa on arrival
# Laos | Visa not required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Free visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa on arrival
# Mauritania | Visa on arrival
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa not required
# Montenegro | Visa required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | Visa not required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa on arrival
# Paraguay | Visa required
# Peru | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa not required
# Saint Kitts and Nevis | eVisa
# Saint Lucia | Visa on arrival
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visa on arrival !Free Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Electronic Travel Authorization
# Sudan | Visa required
# Suriname | Visa not required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa on arrival
# Tanzania | Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa on arrival
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa not required
# Yemen | Visa required
# Zambia | eVisa
# Zimbabwe | eVisa
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# Abkhazia | Visa required
# Mount Athos | Special permit required
# Crimea | Visa required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access Permit required
# Faroe Islands | Visa required
# Gibraltar | Visa required
# Guernsey | Visa required
# Isle of Man | Visa required
# Jan Mayen | Permit required
# Jersey | Visa required
# Kosovo | Visa required
# Nagorno-Karabakh Republic | Visa required
# Russia | Special authorization required
# South Ossetia | Visa not required
# Transnistria | Visa not required
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# EritreaoutsideAsmara | Travel permit required
# Mayotte | Visa required
# Réunion | Visa required
# Ascension Island | Entry Permit required
# Saint Helena | Visitor's Pass required
# Tristan da Cunha | Permission required
# Sahrawi Arab Democratic Republic |
# Somaliland | Visa on arrival
# Sudan | Travel permit required
# Darfur | Travel permit required
# Visitor to | Visa requirement
# Hainan | Visa required
# Hong Kong | Visa not required
# IndiaPAP/RAP | PAP/RAP required
# Kazakhstan | Special permission required
# Kish Island | Visa not required
# Macao | Visa not required
# Maldives | Permission required
# Palestine | Visa required
# Taiwan | eVisa
# Gorno-Badakhshan Autonomous Province | OIVR permit required
# Korean Demilitarized Zone | Restricted zone.
# UNDOF ZoneandGhajar | Restricted zone.
# Yemen | Special permission required
# Visitor to | Visa requirement
# Anguilla | Visa required
# Aruba | Visa required
# Bermuda | Visa required
# Bonaire,St. EustatiusandSaba | Visa required
# British Virgin Islands | Visa required
# Cayman Islands | Visa required
# Curacao | Visa required
# French Guiana | Visa required
# French West Indies | Visa required
# Greenland | Visa required
# Montserrat | eVisa
# Puerto Rico | Visa required
# Saint Pierre and Miquelon | Visa required
# Sint Maarten | Visa required
# Turks and Caicos Islands | Visa required
# U.S. Virgin Islands | Visa required
# Visitor to | Visa requirement
# American Samoa | Visa required
# Ashmore and Cartier Islands | Special authorisation required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# Lau Province | Special permission required
# French Polynesia | Visa required
# Guam | Visa required
# New Caledonia | Visa required
# Northern Mariana Islands | Visa required
# Niue | Visa on arrival
# Pitcairn Islands | Visa not required
# United States Minor Outlying Islands | Special permits required
# Wallis and Futuna | Visa required
# Visitor to | Visa requirement
# Falkland Islands | Visa required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica |
# Fetching data for Qatar...
# 请求Qatar成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa on arrival
# Australia | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | eVisa
# Bahamas | Visa not required
# Bahrain | GCC !Visa not required
# Bangladesh | Visa on arrival
# Barbados | Visa required
# Belarus | Visa not required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa on arrival
# Bosnia and Herzegovina | Visa not required
# Botswana | Visa not required
# Brazil | Visa required
# Brunei | Visa on arrival
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa not required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa not required
# Ecuador | Visa not required
# Egypt | Visa not required
# El Salvador | Visa not required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa required
# Georgia | Visa not required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa not required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa not required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa not required
# Kazakhstan | Visa required
# Kenya | eVisa
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa not required
# Kuwait | GCC !Visa not required
# Kyrgyzstan | Visa not required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa not required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa on arrival
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa not required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa not required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealand | Visa not required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | GCC !Visa not required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# ...
# Mongolia | Visa required
# Montenegro | Visa not required
# Morocco | Visa not required
# Mozambique | Visa on arrival
# Myanmar | eVisa
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa not required
# New Zealand | Visa not required
# Nicaragua | Visa not required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa not required
# Oman | Visa on arrival
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa on arrival
# Paraguay | Visa not required
# Peru | Visa not required
# Philippines | Visa not required
# Poland | Visa not required
# Portugal | Visa not required
# Qatar | Visa on arrival
# Romania | Visa not required
# Russia | Visa not required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa not required
# Saint Lucia | Visa not required
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa not required
# São Tomé and Príncipe | eVisa
# Saudi Arabia | Visa required
# Senegal | Visa not required
# Serbia | Visa not required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Singapore | Visa not required
# Sierra Leone | Visa required
# Slovakia | Visa not required
# Slovenia | Visa not required
# Solomon Islands | Visa on arrival !Visitor's permit on arrival
# Somalia | Travel banned
# South Africa | Visa not required
# South Sudan | Visa required
# Spain | Visa not required
# Sri Lanka | Electronic Travel Authorization
# Sudan | Visa required
# Suriname | Visa not required
# Swaziland | Visa not required
# Sweden | Visa not required
# Switzerland | Visa not required
# Syria | Travel banned
# Tajikistan | Visa on arrival
# Tanzania | Visa on arrival
# Thailand | Visa not required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa on arrival
# Trinidad and Tobago | Visa not required
# Tunisia | Visa not required
# Turkey | Visa not required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa not required
# United Arab Emirates | Visa on arrival
# United Kingdom | Visa not required
# United States | Visa not required !Visa Waiver Program
# Uruguay | Visa not required
# Uzbekistan | Visa required
# Vanuatu | Visa not required
# Vatican City | Visa not required
# Venezuela | Visa not required
# Vietnam | Visa not required
# Yemen | Travel banned
# Zambia | Visa on arrival
# Zimbabwe | Visa on arrival
# 正在处理第 2 个表格...
# Visitor to | Visa requirement
# Abkhazia | Visa required
# Mount Athos | Special permit required
# Belovezhskaya Pushcha National Park | Visa not required
# Crimea | Visa not required
# Turkish Republic of Northern Cyprus | Visa not required
# UN Buffer Zone in Cyprus | Access Permit required
# Faroe Islands | Visa not required
# Gibraltar | Visa not required
# Guernsey | Visa not required
# Isle of Man | Visa not required
# Jan Mayen | Permit required
# Jersey | Visa not required
# Kosovo | Visa not required
# Nagorno-Karabakh Republic | Visa required
# Russia | Special authorization required
# South Ossetia | Visa not required
# Transnistria | Visa not required
# Visitor to | Visa requirement
# British Indian Ocean Territory | Special permit required
# EritreaoutsideAsmara | Travel permit required
# Mayotte | Visa not required
# Réunion | Visa not required
# Ascension Island | Entry Permit required
# Saint Helena | Visitor's Pass required
# Tristan da Cunha | Permission required
# Sahrawi Arab Democratic Republic |
# Somaliland | Travel banned
# Sudan | Travel permit required
# Darfur | Travel permit required
# Visitor to | Visa requirement
# Hainan | Visa on arrival
# North KoreaGaesung Industrial Complex | Special permission required
# Hong Kong | Visa not required
# IndiaPAP/RAP | PAP/RAP required
# Kazakhstan | Special permission required
# Kish Island | Visa not required
# Macao | Visa not required
# SabahandSarawak | Visa not required
# Maldives | Permission required
# Palestine | Visa not required
# Taiwan | Visa not required
# Gorno-Badakhshan Autonomous Province | OIVR permit required
# Tibet Autonomous Region | TTP required
# Turkmenistan | Special permit required
# Korean Demilitarized Zone | Special permission required
# UNDOF ZoneandGhajar | Restricted zone.
# Yemen | Special permission required
# Visitor to | Visa requirement
# Anguilla | Visa not required
# Aruba | Visa not required
# Bermuda | Visa not required
# Bonaire,St. EustatiusandSaba | Visa not required
# British Virgin Islands | Visa not required
# San AndrésandLeticia | Tourist Card on arrival
# Cayman Islands | Visa required
# Curacao | Visa not required
# French Guiana | Visa not required
# French West Indies | Visa not required
# Greenland | Visa not required
# Margarita Island | Visa not required
# Montserrat | Visa not required
# Puerto Rico | Visa not required
# Saint Pierre and Miquelon | Visa not required
# Sint Maarten | Visa not required
# Turks and Caicos Islands | Visa not required
# U.S. Virgin Islands | Visa not required
# Visitor to | Visa requirement
# American Samoa | Entry permit required
# Ashmore and Cartier Islands | Special authorisation required
# Clipperton Island | Special permit required
# Cook Islands | Visa not required
# Lau Province | Special permission required
# French Polynesia | Visa not required
# Guam | Visa not required
# New Caledonia | Visa not required
# Niue | Visa on arrival
# Northern Mariana Islands | Visa not required
# Pitcairn Islands | Visa not required
# United States Minor Outlying Islands | Special permits required
# Wallis and Futuna | Visa not required
# Visitor to | Visa requirement
# Galápagos | Pre-registration required
# Visitor to | Visa requirement
# Falkland Islands | Visa not required
# South Georgia and the South Sandwich Islands | Permit required
# Antarctica |
# Fetching data for Syria...
# 请求Syria成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa required
# Australia | Visa required
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bhutan | Visa required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Visa required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa required
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | Visa required
# Gambia | Visa required
# Georgia | Visa required
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hungary | Visa required
# Iceland | Visa required
# India | Visa required
# Indonesia | Visa required
# Iran | Visa not required
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa required
# Kazakhstan | Visa required
# Kenya | Visa required
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | Visa required
# Kyrgyzstan | Visa required
# Laos | Visa required
# Latvia | Visa required
# Lebanon | Visa required
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa not required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa not required
# Mauritius | Visa required
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa required
# Netherlands | Visa required
# New Zealand | Visa required
# Nicaragua | Visa required
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa required
# Saint Vincent and the Grenadines | Visa required
# Samoa | Visa on arrival !Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visa on arrival !Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa required
# Sudan | Visa not required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Tajikistan | Visa on arrival
# Tanzania | Visa on arrival
# Thailand | Visa required
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdom | Visa required
# United States | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa on arrival
# Zambia | Visa required
# Zimbabwe | Visa required
# Fetching data for Bhutan...
# 请求Bhutan成功
# 正在处理第 1 个表格...
# Afghanistan | Visa required
# Albania | Visa required
# Algeria | Visa required
# Andorra | Visa required
# Angola | Visa required
# Antigua and Barbuda | Electronic Entry Visa
# Argentina | Visa required
# Armenia | Visa on arrival
# Australiaand territories | Online Visitor e600 visa
# Austria | Visa required
# Azerbaijan | Visa required
# Bahamas | Visa required
# Bahrain | Visa required
# Bangladesh | Visa not required
# Barbados | Visa required
# Belarus | Visa required
# Belgium | Visa required
# Belize | Visa required
# Benin | Visa required
# Bolivia | Visa required
# Bosnia and Herzegovina | Visa required
# Botswana | Visa required
# Brazil | Visa required
# Brunei | Visa required
# Bulgaria | Visa required
# Burkina Faso | Visa required
# Burundi | Visa required
# Cambodia | Visa on arrival
# Cameroon | Visa required
# Canada | Visa required
# Cape Verde | Visa on arrival
# Central African Republic | Visa required
# Chad | Visa required
# Chile | Visa required
# China | Visa required
# Colombia | Visa not required
# Comoros | Visa on arrival
# Republic of the Congo | Visa required
# Democratic Republic of the Congo | Visa required
# Costa Rica | Visa required
# Cote d'Ivoire !Côte d'Ivoire | Visa required
# Croatia | Visa required
# Cuba | Tourist Card required
# Cyprus | Visa required
# Czech Republic | Visa required
# Denmark | Visa required
# Djibouti | Visa on arrival
# Dominica | Visa not required
# Dominican Republic | Visa required
# Ecuador | Visa not required
# Egypt | Visa required
# El Salvador | Visa required
# Equatorial Guinea | Visa required
# Eritrea | Visa required
# Estonia | Visa required
# Ethiopia | Visa required
# Fiji | Visa required
# Finland | Visa required
# France | Visa required
# Gabon | eVisa
# Gambia | Visa not required
# Georgia | eVisa
# Germany | Visa required
# Ghana | Visa required
# Greece | Visa required
# Grenada | Visa required
# Guatemala | Visa required
# Guinea | Visa required
# Guinea-Bissau | Visa on arrival
# Guyana | Visa required
# Haiti | Visa not required
# Honduras | Visa required
# Hong Kong | Visa not required
# Hungary | Visa required
# Iceland | Visa required
# India | Freedom of movement
# Indonesia | Visa not required
# Iran | Visa on arrival
# Iraq | Visa required
# Ireland | Visa required
# Israel | Visa required
# Italy | Visa required
# Jamaica | Visa required
# Japan | Visa required
# Jordan | Visa on arrival
# Kazakhstan | Visa required
# Kenya | Visa on arrival
# Kiribati | Visa required
# North Korea | Visa required
# South Korea | Visa required
# Kuwait | eVisa
# Kyrgyzstan | Visa required
# Laos | Visa on arrival
# Latvia | Visa required
# Lebanon | Visa on arrival
# Lesotho | Visa required
# Liberia | Visa required
# Libya | Visa required
# Liechtenstein | Visa required
# Lithuania | Visa required
# Luxembourg | Visa required
# Macedonia | Visa required
# Madagascar | Visa on arrival
# Malawi | Visa required
# Malaysia | Visa required
# Maldives | Visa on arrival
# Mali | Visa required
# Malta | Visa required
# Marshall Islands | Visa required
# Mauritania | Visa on arrival
# Mauritius | Visa on arrival
# Mexico | Visa required
# Micronesia | Visa not required
# Moldova | Visa required
# Monaco | Visa required
# Mongolia | Visa required
# Montenegro | Visa required
# Morocco | Visa required
# Mozambique | Visa on arrival
# Myanmar | Visa required
# Namibia | Visa required
# Nauru | Visa required
# Nepal | Visa on arrival
# Netherlands | Visa required
# New Zealandand territories | Visa required
# Nicaragua | Visa on arrival
# Niger | Visa required
# Nigeria | Visa required
# Norway | Visa required
# Oman | Visa required
# Pakistan | Visa required
# Palau | Visa on arrival
# Panama | Visa not required
# Papua New Guinea | Visa required
# Paraguay | Visa required
# Peru | Visa required
# Philippines | Visa not required
# Poland | Visa required
# Portugal | Visa required
# Qatar | Visa required
# Romania | Visa required
# Russia | Visa required
# Rwanda | Visa required
# Saint Kitts and Nevis | Visa required
# Saint Lucia | Visa on arrival
# Saint Vincent and the Grenadines | Visa not required
# Samoa | Entry Permit on arrival
# San Marino | Visa required
# São Tomé and Príncipe | Visa required
# Saudi Arabia | Visa required
# Senegal | Visa required
# Serbia | Visa required
# Seychelles | Visitor's Permit on arrival
# Sierra Leone | Visa required
# Singapore | Visa not required
# Slovakia | Visa required
# Slovenia | Visa required
# Solomon Islands | Visa required
# Somalia | Visa required
# South Africa | Visa required
# South Sudan | Visa required
# Spain | Visa required
# Sri Lanka | Visa on arrival
# Sudan | Visa required
# Suriname | Visa required
# Swaziland | Visa required
# Sweden | Visa required
# Switzerland | Visa required
# Syria | Visa required
# Tajikistan | Visa required
# Tanzania | Visa on arrival
# Thailand | Visa on arrival
# Timor-Leste | Visa on arrival
# Togo | Visa on arrival
# Tonga | Visa required
# Trinidad and Tobago | Visa required
# Tunisia | Visa required
# Turkey | Visa required
# Turkmenistan | Visa required
# Tuvalu | Visa on arrival
# Uganda | Visa on arrival
# Ukraine | Visa required
# United Arab Emirates | Visa required
# United Kingdomexcluding some Overseas territories | Visa required
# United Statesand territories | Visa required
# Uruguay | Visa required
# Uzbekistan | Visa required
# Vanuatu | Visa required
# Vatican City | Visa required
# Venezuela | Visa required
# Vietnam | Visa required
# Yemen | Visa required
# Zambia | Visa on arrival
# Zimbabwe | eVisa
# 成功爬取完成57个国家的数据
# Visa matrix saved to visa_G_2017.csv
